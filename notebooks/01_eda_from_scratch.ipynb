# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (12,6)
plt.rcParams['font.size'] = 12
PALETTE = ['#2E75B6', '#27AE60', '#E74C3C', '#FF6B35', '#8E44AD', '#1ABC9C']
print('Libraries loaded.')
# Out:
# Libraries loaded.

# %%
import os
print(os.getcwd())
# Out:
# /Users/jaivaranasi/Downloads/SaaS-Product-Engagement-Analysis/notebooks

# %%
os.listdir('../data/cleaned/')
# Out:
# ['.gitkeep']

# %%
import shutil

source = '/Users/jaivaranasi/Downloads/archive/'
dest = '../data/raw/'

for f in os.listdir(source):
    if f.startswith('ravenstack') and f.endswith('.csv'):
        shutil.copy(source + f, dest + f)
        print(f'Copied: {f}')
# Out:
# Copied: ravenstack_feature_usage.csv
# Copied: ravenstack_subscriptions.csv
# Copied: ravenstack_support_tickets.csv
# Copied: ravenstack_churn_events.csv
# Copied: ravenstack_accounts.csv

# %%
accounts = pd.read_csv('../data/raw/ravenstack_accounts.csv')
print(f'Accounts: {accounts.shape[0]} rows, {accounts.shape[1]} columns')
print(accounts.columns.tolist())
# Out:
# Accounts: 500 rows, 10 columns
# ['account_id', 'account_name', 'industry', 'country', 'signup_date', 'referral_source', 'plan_tier', 'seats', 'is_trial', 'churn_flag']
